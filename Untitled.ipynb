# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()

# %%
meta = pd.read_csv("/home/michael/Downloads/plasticc_train_grid/data/plasticc_train_meta.csv")
trainX = pd.read_csv("/home/michael/Downloads/plasticc_train_grid/data/plasticc_train_pred.csv", index_col=['object_id', 'time'])
# Out:
# /home/michael/miniconda3/envs/ust/lib/python3.8/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
trainX = trainX.drop(columns='Unnamed: 0')

# %%
trainX
# Out:
#                                    flux_u      flux_g      flux_r      flux_i  \
# object_id          time
# plasticc_000000615 59739.0415   -4.725665 -419.790535 -169.001661 -132.252283
#                    59744.0415   -6.345849 -421.438024 -170.656938 -133.889210
#                    59749.0415 -172.597460 -592.311909 -340.626173 -297.393207
#                    59754.0415 -272.517049 -679.923062 -407.163132 -342.316779
#                    59759.0415   -7.474273 -422.532283 -171.692245 -134.854279
# ...                                   ...         ...         ...         ...
# plasticc_130779836 60672.0046  140.177690  188.159358  483.883362  186.275428
#                    60677.0046  138.068535  181.552322  475.140413  180.513731
#                    60682.0046  135.664612  175.148859  466.970002  175.203135
#                    60687.0046  133.050372  168.986996  459.361147  170.322124
#                    60692.0046  130.296482  163.093547  452.296563  165.847264
#
# ...

# %%
X, y = meta[['object_id']], meta[['class']]

# %%
trainX.shape, len(y)
sns.countplot(y, nor)

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
import pandas as pd
from sktime.utils.load_data import load_from_arff_to_dataframe

# %%
X, y = load_from_arff_to_dataframe('dataset/Shapelet_ucr/Chinatown/Chinatown_TRAIN.arff')
y[:5] = '5'

# %%
u_res, y_res = RandomOverSampler(random_state=0).fit_resample(X, y)

# %%
sns.countplot(y_res)

# %%
u_res
# Out:
#                                                 dim_0
# 0   0      573.0
# 1      375.0
# 2      301.0
# 3      ...
# 1   0      394.0
# 1      264.0
# 2      140.0
# 3      ...
# 2   0      603.0
# 1      348.0
# 2      176.0
# 3      ...
# 3   0      428.0
# 1      309.0
# 2      199.0
# 3      ...
# 4   0      372.0
# 1      310.0
# 2      203.0
# 3      ...
# 5   0      448.0
# 1      344.0
# 2      183.0
# 3      ...
# 6   0      621.0
# 1      322.0
# 2      221.0
# 3      ...
# 7   0      597.0
# 1      409.0
# 2      142.0
# 3      ...
# 8   0      525.0
# 1      431.0
# 2      248.0
# 3      ...
# 9   0      587.0
# 1      382.0
# 2      165.0
# 3      ...
# 10  0      144.0
# 1       73.0
# 2       21.0
# 3      ...
# 11  0      141.0
# 1       63.0
# 2       51.0
# 3      ...
# 12  0       67.0
# 1       67.0
# 2      107.0
# 3      ...
# 13  0       69.0
# 1       54.0
# 2       35.0
# 3      ...
# 14  0      142.0
# 1      104.0
# 2       55.0
# 3      ...
# ...
